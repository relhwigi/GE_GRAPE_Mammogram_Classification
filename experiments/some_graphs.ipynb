# %% [markdown]
# # **Machine Learning using Grammatical Evolution**
# ### Classification of mammogram segments as containing or not containing suspicious growth.
# Ranya El-Hwigi 18227449

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
scores = [0.536465200194296, 0.5393102491152592, 0.5559641940184581, 0.609187426271598, 0.6271598084796336, 0.6451321906876691, 0.6435361876344459, 0.6488793282908889, 0.6484629796683089, 0.6503365484699188]
plt.plot(accuracies, color='#4d9900', label="Test fitness")
plt.legend(fontsize=12)
plt.xlabel('Experiments', fontsize=14)
plt.ylabel('Best Individual Test Fitness', fontsize=14)
plt.title('Best Fitness over experiments', fontsize=16)
plt.show()

# %%
TPR = [0.5793199167244969, 0.5850104094378904, 0.646911866759195, 0.9108952116585705, 0.7678001387925052, 0.8695350451075642, 0.862734212352533, 0.8680083275503123, 0.8442748091603054, 0.8560721721027065]
TNR = [0.493616430752151, 0.493616430752151, 0.4650291423813489, 0.3075215098529004, 0.4865389952817097, 0.42076047737996114, 0.424368581737441, 0.4297807382736608, 0.45267832361920624, 0.4446294754371357]
plt.plot(TPR, color='green', label="True Postive Rate")
plt.plot(TNR, color='blue', label="True Negative Rate")
plt.legend(fontsize=12)
plt.xlabel('Experiments', fontsize=14)
plt.ylabel('Rate', fontsize=14)
plt.title('Best Individual True Positive and True Negative Rates', fontsize=16)
plt.show()

# %%
FPR = [0.506383569247849, 0.506383569247849, 0.5349708576186512, 0.6924784901470996, 0.5134610047182903, 0.5792395226200389, 0.5756314182625589, 0.5702192617263392, 0.5473216763807938, 0.5553705245628643]
TPR = [0.5793199167244969, 0.5850104094378904, 0.646911866759195, 0.9108952116585705, 0.7678001387925052, 0.8695350451075642, 0.862734212352533, 0.8680083275503123, 0.8442748091603054, 0.8560721721027065]
plt.plot(TPR, color='green', label="True Postive Rate")
plt.plot(FPR, color='red', label="False Positive Rate")
plt.legend(fontsize=12)
plt.xlabel('Experiments', fontsize=14)
plt.ylabel('Rate', fontsize=14)
plt.title('Best Individual True Positive and False Positive Rates', fontsize=16)
plt.show()

# %%
scores = [0.5364681737383239, 0.5393134200950207, 0.5559705045702719, 0.6092083607557355, 0.6271695670371076, 0.6451477612437626, 0.6435513970449871, 0.6488945329119865, 0.6484765663897558, 0.650350823769921]
plt.plot(accuracies, color='red', label="auc")
plt.legend(fontsize=12)
plt.xlabel('Experiments', fontsize=14)
plt.ylabel('AUC score', fontsize=14)
plt.title('Best Individual Area Under the Curve score', fontsize=16)
plt.show()
